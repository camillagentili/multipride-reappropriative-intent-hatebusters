# %% [markdown]
# # 1. Setup

# %%
import io
import numpy as np
import pandas as pd
from tqdm import tqdm
import os
import joblib
# !pip install spacy
# !python -m spacy download en_core_web_sm
# !python -m spacy download it_core_news_sm
# !python -m spacy download es_core_news_sm
# Out:
# Requirement already satisfied: spacy in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (3.7.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from spacy) (1.0.15)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from spacy) (3.0.12)
# Requirement already satisfied: jinja2 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from spacy) (2.11.3)
# Requirement already satisfied: packaging>=20.0 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from spacy) (20.9)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from spacy) (2.4.8)
# Requirement already satisfied: setuptools in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from spacy) (52.0.0.post20210125)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from spacy) (2.32.4)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from spacy) (2.0.10)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from spacy) (1.1.3)
# Requirement already satisfied: numpy>=1.15.0 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from spacy) (1.22.4)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from spacy) (1.0.5)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from spacy) (0.4.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from spacy) (2.10.6)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from spacy) (4.67.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from spacy) (0.20.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from spacy) (3.4.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from spacy) (3.0.12)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from spacy) (8.2.5)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from spacy) (2.0.11)
# Requirement already satisfied: language-data>=1.2 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from langcodes<4.0.0,>=3.2.0->spacy) (1.3.0)
# Requirement already satisfied: marisa-trie>=1.1.0 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy) (1.2.1)
# Requirement already satisfied: pyparsing>=2.0.2 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from packaging>=20.0->spacy) (2.4.7)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.27.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.13.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2025.4.26)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4.4)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.1.5)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.7.11)
# Requirement already satisfied: rich>=10.11.0 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from typer<1.0.0,>=0.3.0->spacy) (14.2.0)
# Requirement already satisfied: shellingham>=1.3.0 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: click>=8.0.0 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from typer<1.0.0,>=0.3.0->spacy) (8.1.8)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from weasel<0.5.0,>=0.1.0->spacy) (7.3.1)
# Requirement already satisfied: typer-slim<1.0.0,>=0.3.0 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from weasel<0.5.0,>=0.1.0->spacy) (0.20.0)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from weasel<0.5.0,>=0.1.0->spacy) (0.20.0)
# Requirement already satisfied: wrapt in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy) (1.12.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from jinja2->spacy) (1.1.1)
# Collecting en-core-web-sm==3.7.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.7.1/en_core_web_sm-3.7.1-py3-none-any.whl (12.8 MB)
#      |████████████████████████████████| 12.8 MB 4.4 MB/s eta 0:00:01
# Requirement already satisfied: spacy<3.8.0,>=3.7.2 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from en-core-web-sm==3.7.1) (3.7.5)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.2.5)
# Requirement already satisfied: numpy>=1.15.0 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.22.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.12)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.1.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.10.6)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.67.1)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.11)
# Requirement already satisfied: jinja2 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.11.3)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.15)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.5)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.10)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.20.0)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.4.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.32.4)
# Requirement already satisfied: packaging>=20.0 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (20.9)
# Requirement already satisfied: setuptools in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (52.0.0.post20210125)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.12)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.4.8)
# Requirement already satisfied: language-data>=1.2 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.3.0)
# Requirement already satisfied: marisa-trie>=1.1.0 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.2.1)
# Requirement already satisfied: pyparsing>=2.0.2 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from packaging>=20.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.4.7)
# Requirement already satisfied: pydantic-core==2.27.2 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.27.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.7.0)
# Requirement already satisfied: typing-extensions>=4.12.2 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.13.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2025.4.26)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.26.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.10)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.4.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.1.5)
# Requirement already satisfied: shellingham>=1.3.0 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (14.2.0)
# Requirement already satisfied: click>=8.0.0 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.1.8)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.19.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.1.2)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (7.3.1)
# Requirement already satisfied: typer-slim<1.0.0,>=0.3.0 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.20.0)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.20.0)
# Requirement already satisfied: wrapt in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.12.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from jinja2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.1.1)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# Collecting it-core-news-sm==3.7.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/it_core_news_sm-3.7.0/it_core_news_sm-3.7.0-py3-none-any.whl (13.0 MB)
#      |████████████████████████████████| 13.0 MB 7.6 MB/s eta 0:00:01
# Requirement already satisfied: spacy<3.8.0,>=3.7.0 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from it-core-news-sm==3.7.0) (3.7.5)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (0.20.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (2.10.6)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (2.4.8)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (2.32.4)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (8.2.5)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (4.67.1)
# Requirement already satisfied: setuptools in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (52.0.0.post20210125)
# Requirement already satisfied: numpy>=1.15.0 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (1.22.4)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (2.0.11)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (0.4.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (1.1.3)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (2.0.10)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (3.4.1)
# Requirement already satisfied: packaging>=20.0 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (20.9)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (1.0.15)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (3.0.12)
# Requirement already satisfied: jinja2 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (2.11.3)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (1.0.5)
# Requirement already satisfied: language-data>=1.2 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (1.3.0)
# Requirement already satisfied: marisa-trie>=1.1.0 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (1.2.1)
# Requirement already satisfied: pyparsing>=2.0.2 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from packaging>=20.0->spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (2.4.7)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (2.27.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (4.13.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (1.26.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (2025.4.26)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (0.1.5)
# Requirement already satisfied: rich>=10.11.0 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (14.2.0)
# Requirement already satisfied: click>=8.0.0 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (1.5.4)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (2.19.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (3.0.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (0.1.2)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (0.20.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (7.3.1)
# Requirement already satisfied: typer-slim<1.0.0,>=0.3.0 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (0.20.0)
# Requirement already satisfied: wrapt in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (1.12.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from jinja2->spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (1.1.1)
# ✔ Download and installation successful
# You can now load the package via spacy.load('it_core_news_sm')
# Collecting es-core-news-sm==3.7.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/es_core_news_sm-3.7.0/es_core_news_sm-3.7.0-py3-none-any.whl (12.9 MB)
#      |████████████████████████████████| 12.9 MB 5.6 MB/s eta 0:00:01
# Requirement already satisfied: spacy<3.8.0,>=3.7.0 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from es-core-news-sm==3.7.0) (3.7.5)
# Requirement already satisfied: setuptools in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (52.0.0.post20210125)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (3.0.12)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (3.4.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (4.67.1)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (2.0.11)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (1.0.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (1.1.3)
# Requirement already satisfied: packaging>=20.0 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (20.9)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (2.4.8)
# Requirement already satisfied: numpy>=1.15.0 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (1.22.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (2.32.4)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (3.0.12)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (2.0.10)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (8.2.5)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (0.20.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (2.10.6)
# Requirement already satisfied: jinja2 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (2.11.3)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (1.0.15)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (0.4.3)
# Requirement already satisfied: language-data>=1.2 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (1.3.0)
# Requirement already satisfied: marisa-trie>=1.1.0 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (1.2.1)
# Requirement already satisfied: pyparsing>=2.0.2 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from packaging>=20.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (2.4.7)
# Requirement already satisfied: pydantic-core==2.27.2 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (2.27.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (4.13.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (0.7.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (2025.4.26)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (1.26.4)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (0.1.5)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (0.7.11)
# Requirement already satisfied: shellingham>=1.3.0 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (1.5.4)
# Requirement already satisfied: click>=8.0.0 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (8.1.8)
# Requirement already satisfied: rich>=10.11.0 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (14.2.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (0.1.2)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (7.3.1)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (0.20.0)
# Requirement already satisfied: typer-slim<1.0.0,>=0.3.0 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (0.20.0)
# Requirement already satisfied: wrapt in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (1.12.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/giulia/opt/anaconda3/lib/python3.8/site-packages (from jinja2->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (1.1.1)
# ✔ Download and installation successful
# You can now load the package via spacy.load('es_core_news_sm')

# %% [markdown]
# # 2. Load data

# %%
train_es = pd.read_csv("train_es.csv", encoding="utf-8")
train_en = pd.read_csv("train_en.csv", encoding="utf-8")
train_it = pd.read_csv("train_it.csv", encoding="utf-8")
test_es = pd.read_csv("es_test.csv", encoding="utf-8")
test_en = pd.read_csv("en_test.csv", encoding="utf-8")
test_it = pd.read_csv("it_test.csv", encoding="utf-8")

# %% [markdown]
# # 3. Dataset Integration (Italian, English, Spanish)

# %% [markdown]
# We first merge the three monolingual datasets into a multilingual dataset (one for training and one for validation).
# This allows us to train a unified model capable of handling input from different languages, increasing data size and improving model robustness.

# %%
#TRAINING SET

# 1. Adding missing 'bio' column to English dataset
train_en["bio"] = ""   # English dataset has no biography field

# 2. Select and reorder columns for IT and ES (they already have bio)
train_it = train_it[["id", "text", "bio", "label", "lang"]]
train_es = train_es[["id", "text", "bio", "label", "lang"]]

# 3. Select and reorder columns for EN (we just added bio)
train_en = train_en[["id", "text", "bio", "label", "lang"]]

# 4. Concatenate all datasets into a single multilingual dataset
train_multi = pd.concat([train_it, train_en, train_es], ignore_index=True)

# 5. Quick checks
print(train_multi.head())
print("\nShape:", train_multi.shape)
print("\nColumns:", train_multi.columns.tolist())
print("\nLabel distribution:")
print(train_multi["label"].value_counts(normalize=True))
train_multi.to_csv("train_Multi.csv")

#TEST SET

# 1. Adding missing 'bio' column to English dataset
test_en["bio"] = ""   # English dataset has no biography field

# 2. Select and reorder columns for IT and ES (they already have bio)
test_it = test_it[["id", "text", "bio", "lang"]]
test_es = test_es[["id", "text", "bio", "lang"]]

# 3. Select and reorder columns for EN (we just added bio)
test_en = test_en[["id", "text", "bio", "lang"]]

# 4. Concatenate all datasets into a single multilingual dataset
test_multi = pd.concat([test_it, test_en, test_es], ignore_index=True)

# 5. Quick checks
print(test_multi.head())
print("\nShape:", test_multi.shape)
print("\nColumns:", test_multi.columns.tolist())
test_multi.to_csv("test_Multi.csv")
# Out:
#         id                                               text  \
# 0  it_1231  La destra Italiana pur di non dire che loro od...
# 1  it_1713  "Presupporre che tutti i bisessuali non sono m...
# 2  it_1474  Se i diritti devono essere uguali, voglio che ...
# 3    it_58  che poi molti uomini trans subiscono lesbofobi...
# 4   it_511  Che poi è l’etero medio come Pio e Amedeo che ...
#
#                                                  bio  label lang
# 0  Il rispetto per il prossimo qualunque sia il s...      0   it
# 1                   𝓕𝓲𝓵𝓵𝓮𝓭 𝔀𝓲𝓽𝓱 𝓯𝓾𝓻𝔂 𝓪𝓷𝓭 𝓼𝓽𝓪𝓻𝓻𝔂 𝓮𝔂𝓮𝓭      0   it
# 2                       User Experience Designer URL      0   it
# 3               no matter where i go, you're there …      0   it
# 4  T'appartengo ed io ci tengo \nE se prometto po...      0   it
#
# Shape: (2988, 5)
#
# Columns: ['id', 'text', 'bio', 'label', 'lang']
#
# Label distribution:
# label
# 0    0.85676
# 1    0.14324
# Name: proportion, dtype: float64
#         id                                               text  \
# 0   it_406  @USER @USER Oggi avrò di che parlare coi colle...
# 1   it_138  @USER Il problema è che c’è tantissima omofobi...
# 2  it_1622  dua lipa bella hadid kendall jenner hunter sch...
# 3  it_1401  🏳️‍🌈🏳️‍🌈🏳️‍🌈\nFatelo per lui, per tutte le vit...
# 4   it_807  No Pride fisico, ma potete sempre dare uno sgu...
#
#                                                  bio lang
# 0                                                NaN   it
# 1  Slave, passive, submissive. Available for Mast...   it
# 2             ˗ˏˋyou bring me homeˊ˗ she / her ›››››   it
# 3  Cit - Allora scusate ma se io mi metto una bot...   it
# 4  Mi piace disegnare, mi piacciono i videogiochi...   it
#
# Shape: (1995, 4)
#
# Columns: ['id', 'text', 'bio', 'lang']

# %% [markdown]
# # 4. Concatenatenation of the text and the biography into a single field:

# %%
#TRAINING SET

train_multi["bio"] = train_multi["bio"].fillna("")
train_multi["text_full"] = train_multi["text"] + " " + train_multi["bio"]

#TEST SET

test_multi["bio"] = test_multi["bio"].fillna("")
test_multi["text_full"] = test_multi["text"] + " " + test_multi["bio"]

# %% [markdown]
# # 5. Multilingual Text Pre-processing

# %% [markdown]
# This section performs the full preprocessing pipeline on the multilingual datasets.
# The code loads the spaCy models for Italian, English, and Spanish, defines multilingual stopwords, and applies language-specific lemmatization. Before lemmatization, the text is cleaned by removing URLs, mentions, numbers, punctuation, emojis, and extra whitespace.

# %%
import re
import string
import nltk
from nltk.corpus import stopwords
import spacy

# 0. Loading spaCy models

nlp_en = spacy.load("en_core_web_sm", disable=["ner", "parser"])
nlp_it = spacy.load("it_core_news_sm", disable=["ner", "parser"])
nlp_es = spacy.load("es_core_news_sm", disable=["ner", "parser"])


# 1. Downloading NLTK resources 

nltk.download('stopwords')


# 2. Multilingual stopwords 

stop_it = set(stopwords.words('italian'))
stop_en = set(stopwords.words('english'))
stop_es = set(stopwords.words('spanish'))
STOPWORDS = stop_it.union(stop_en).union(stop_es)


# 3. Lemmatization (stopwords removed *inside* this function)

def lemmatize_multilingual(text_full, lang, stopwords_set=STOPWORDS):
    if not isinstance(text_full, str) or text_full.strip() == "":
        return ""

    # choose spaCy model based on language
    if lang == "en":
        doc = nlp_en(text_full)
    elif lang == "it":
        doc = nlp_it(text_full)
    elif lang == "es":
        doc = nlp_es(text_full)
    else:
        # fallback to English if unknown
        doc = nlp_en(text_full)

    lemmas = []
    for token in doc:
        if token.is_space or token.is_punct:
            continue
        lemma = token.lemma_.lower()
        # filter stopwords
        if lemma and lemma not in stopwords_set:
            lemmas.append(lemma)

    return " ".join(lemmas)


# 4. Cleaning Functions

def remove_urls(text_full):
    return re.sub(r'https?://\S+|www\.\S+', '', text_full)

def remove_emojis(text_full):
    emoji_pattern = re.compile("["
                               u"\U0001F600-\U0001F64F"
                               u"\U0001F300-\U0001F5FF"
                               u"\U0001F680-\U0001F6FF"
                               u"\U0001F1E0-\U0001F1FF"
                               u"\U00002500-\U00002BEF"
                               u"\U00002702-\U000027B0"
                               u"\U000024C2-\U0001F251"
                               u"\U0001f926-\U0001f937"
                               u"\U00010000-\U0010ffff"
                               u"\u2640-\u2642"
                               u"\u2600-\u2B55"
                               u"\u200d"
                               u"\u23cf"
                               u"\u23e9"
                               u"\u231a"
                               u"\ufe0f"
                               u"\u3030"
                               "]+", flags=re.UNICODE)
    return emoji_pattern.sub(r'', text_full)

def remove_mention(text_full):
    return re.sub(r'@[\w\-]+', '', text_full)

def remove_numbers(text_full):
    return re.sub(r'\d+', '', text_full)

def remove_punctuation(text_full, punctuation=None):
    if punctuation is None:
        punctuation = string.punctuation
    return text_full.translate(str.maketrans(punctuation, ' '*len(punctuation)))

def remove_extra_whitespace(text_full):
    return " ".join(text_full.split())

def remove_retweet(text_full):
    return re.sub(r'^RT\s+', '', text_full)


# 5. Unified preprocessing function

def preprocessing(text_full, lang):
    text_full = str(text_full)
    text_full = remove_emojis(text_full)
    text_full = remove_urls(text_full)
    text_full = remove_mention(text_full)
    text_full = remove_retweet(text_full)
    text_full = remove_numbers(text_full)
    text_full = remove_punctuation(text_full)

    # normalization
    text_full = text_full.lower()
    text_full = remove_extra_whitespace(text_full)

    # lemmatization 
    text_clean = lemmatize_multilingual(text_full, lang)

    return text_clean


# 6. Apply preprocessing to training and test sets

train_multi["text_clean"] = train_multi.apply(
    lambda row: preprocessing(row["text_full"], row["lang"]),
    axis=1
)

test_multi["text_clean"] = test_multi.apply(
    lambda row: preprocessing(row["text_full"], row["lang"]),
    axis=1
)

# Check
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)
pd.set_option('display.expand_frame_repr', False)

train_multi.head()
test_multi.head()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/giulia/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#         id                                                                                                                                                                                                                                                                    text                                                                                                                                                      bio lang                                                                                                                                                                                                                                                                                                                                                                                                                       text_full                                                                                                                                                                                                                                                                                                        text_clean
# 0   it_406                                                        @USER @USER Oggi avrò di che parlare coi colleghi.. un etero analfabeta che conquista l attenzione di una checca alfabetizzata 😎 mi raccomando vai a fare la quarta dose che forse ti aiuta a dimenticarmi. Ciao                                                                                                                                                            it                                                                                                                                                                                                               @USER @USER Oggi avrò di che parlare coi colleghi.. un etero analfabeta che conquista l attenzione di una checca alfabetizzata 😎 mi raccomando vai a fare la quarta dose che forse ti aiuta a dimenticarmi. Ciao                                                                                                                                                    oggi avere parlare con il collega etero analfabeta conquistare attenzione checca alfabetizzato raccomare vai fare quarto doso forse aiutare dimenticare mi ciao
# %% [markdown]
# # 5. Train/Validation Split 80% – 20%

# %% [markdown]
# Before training and evaluating our multilingual models, we split the combined training dataset into a training set and a validation set. This separation allows us to tune hyperparameters, compare different models, and assess performance on unseen data without ever touching the official test set. Stratification ensures that the class imbalance is preserved across both splits, making the evaluation reliable and representative.

# %%
# Importing the function
from sklearn.model_selection import train_test_split

# Splitting the dataset
train_df, val_df = train_test_split(
    train_multi,
    test_size=0.2,               # 20% for validation
    stratify=train_multi["label"],  # <-- CORRECT
    random_state=42
)

# Printing the sizes of the splits
print("Train size:", len(train_df))
print("Val size:", len(val_df))

# Checking label distribution in each split
print("\nTrain label distribution:")
print(train_df["label"].value_counts(normalize=True))

print("\nVal label distribution:")
print(val_df["label"].value_counts(normalize=True))
# Out:
# Train size: 2390
# Val size: 598
#
# Train label distribution:
# label
# 0    0.856904
# 1    0.143096
# Name: proportion, dtype: float64
#
# Val label distribution:
# label
# 0    0.856187
# 1    0.143813
# Name: proportion, dtype: float64

# %% [markdown]
# The training–validation split was successful. The dataset was divided into 2390 training samples and 598 validation samples, keeping exactly the same class imbalance in both sets (~85.7% class 0 and ~14.3% class 1).
# This confirms that stratification worked correctly, ensuring that the validation set is representative of the real label distribution and suitable for reliable model evaluation.

# %% [markdown]
# # 6. Text Representation

# %% [markdown]
# ## BOW

# %% [markdown]
# The Bag-of-Words represents each document as a vector counting how many times each word (or n-gram) appears. It ignores grammar and word order, focusing only on frequency. This makes it simple and effective for text classification.

# %%
text_preprocessed_train = train_df["text_clean"]
text_preprocessed_val   = val_df["text_clean"]

y_train = train_df["label"]
y_val   = val_df["label"]

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
import joblib


# Creating the BOW vectorizer 

vectorizer_bow = CountVectorizer(
    ngram_range=(1,3),      # uni-grams, bi-grams, tri-grams
    max_features=10000      # the most frequent 10.000 n-grams
)


# Fitting on the train set, transformation on train and validation

X_train_bow = vectorizer_bow.fit_transform(text_preprocessed_train).toarray()
X_val_bow   = vectorizer_bow.transform(text_preprocessed_val).toarray()


# dimentions' verification

print("Train BoW shape:", X_train_bow.shape)
print("Val BoW shape:",   X_val_bow.shape)

# Saving the BoW matrices 
joblib.dump(X_train_bow, 'processed_train_bow.save')
joblib.dump(X_val_bow,   'processed_val_bow.save')
# Out:
# Train BoW shape: (2390, 10000)
# Val BoW shape: (598, 10000)
# ['processed_val_bow.save']

# %% [markdown]
# The BoW transformation ran successfully.
# - Training matrix: 2390 samples × 10,000 features
# - Validation matrix: 598 samples × 10,000 features
#
# This confirms that the vectorizer extracted the 10,000 most frequent multilingual n-grams and applied them consistently to both splits.
# Your data is now correctly vectorized and ready for training classification models.

# %% [markdown]
# ## TF-IDF

# %% [markdown]
# TF–IDF (Term Frequency–Inverse Document Frequency) extends BoW by weighting each word according to how important it is in the document relative to the entire corpus. Common words receive lower weights, while distinctive words receive higher weights. This helps highlight more informative terms and often improves performance in text classification tasks.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
import joblib

# 1. Preprocessed texts and labels from the split datasets
text_preprocessed_train = train_df["text_clean"]
text_preprocessed_val   = val_df["text_clean"]

y_train = train_df["label"]
y_val   = val_df["label"]

# 2. Create the TF-IDF vectorizer (multilingual n-grams)
vectorizer_tfidf = TfidfVectorizer(
    ngram_range=(1, 3),    # unigrams, bigrams, trigrams
    max_features=10000,    # 10k most informative n-grams
    lowercase=True
)

# 3. Fit on the training set, transform both train and validation
X_train_tfidf = vectorizer_tfidf.fit_transform(text_preprocessed_train).toarray()
X_val_tfidf   = vectorizer_tfidf.transform(text_preprocessed_val).toarray()

# 4. Check dimensions
print("Train TF-IDF shape:", X_train_tfidf.shape)
print("Val TF-IDF shape:",   X_val_tfidf.shape)

# 5. Save TF-IDF matrices and vectorizer
joblib.dump(X_train_tfidf, "processed_train_tfidf.save")
joblib.dump(X_val_tfidf,   "processed_val_tfidf.save")
joblib.dump(vectorizer_tfidf, "tfidf_vectorizer.save")
# Out:
# Train TF-IDF shape: (2390, 10000)
# Val TF-IDF shape: (598, 10000)
# ['tfidf_vectorizer.save']

# %% [markdown]
# The TF-IDF vectorizer successfully transformed the multilingual training and validation sets into numerical feature matrices of size (2390, 10000) and (598, 10000).
# This means the model extracted the 10,000 most informative n-grams (unigrams, bigrams, trigrams) from the training corpus and applied the same vocabulary to the validation set.

# %% [markdown]
# # 7. Text Classification

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.preprocessing import LabelEncoder
import joblib

# 1. Encode labels (even if they are already 0/1, this keeps the pipeline consistent)

labels_train = train_df["label"]
labels_val   = val_df["label"]

# Initialize LabelEncoder and fit ONLY on the training labels
encoder = LabelEncoder()
encoder.fit(labels_train)

# Transform labels to numeric format
y_train = encoder.transform(labels_train)
y_val   = encoder.transform(labels_val)

# Save the encoder for later use (e.g., on the test predictions)
joblib.dump(encoder, "label_encoder.save")

print("Examples of original labels:", labels_train.unique()[:5])
print("Examples of encoded labels:", y_train[:5])

# 2. Load BoW / TF-IDF matrices previously saved

# --- BoW ---
X_train_bow = joblib.load("processed_train_bow.save")
X_val_bow   = joblib.load("processed_val_bow.save")

print("X_train_bow shape:", X_train_bow.shape)
print("X_val_bow shape:  ", X_val_bow.shape)

# --- TF-IDF ---
X_train_tfidf = joblib.load("processed_train_tfidf.save")
X_val_tfidf   = joblib.load("processed_val_tfidf.save")

print("X_train_tfidf shape:", X_train_tfidf.shape)
print("X_val_tfidf shape:  ", X_val_tfidf.shape)
# Out:
# Examples of original labels: [0 1]
# Examples of encoded labels: [0 0 0 0 1]
# X_train_bow shape: (2390, 10000)
# X_val_bow shape:   (598, 10000)
# X_train_tfidf shape: (2390, 10000)
# X_val_tfidf shape:   (598, 10000)

# %% [markdown]
# BoW and TF-IDF matrices loaded successfully the shapes (2390, 10000) for training and (598, 10000) for validation
# show that:
#
# - You have 2390 training samples and 598 validation samples
# - Each sample is represented by a 10,000-dimensional feature vector
# - Both vectorizers applied 1–3-grams correctly

# %% [markdown]
# ## Support Vector Machines (SVM)

# %% [markdown]
# This cell trains two LinearSVC models using the Bag-of-Words and TF–IDF representations without applying oversampling. The parameter `class_weight='balanced'` compensates for the strong class imbalance by increasing the contribution of minority-class errors during training.

# %%
from sklearn.svm import LinearSVC
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, f1_score


# 1. Linear SVM on Bag-of-Words

clf_bow = LinearSVC(C=0.001, class_weight='balanced', random_state=42)
clf_bow.fit(X_train_bow, y_train)

# Predictions
preds_bow = clf_bow.predict(X_val_bow)

# Macro F1
macro_f1_bow = f1_score(y_val, preds_bow, average='macro')

print("RESULTS: Bag-of-Words + LinearSVC")
print(classification_report(y_val, preds_bow, digits=3))
print("Accuracy:", accuracy_score(y_val, preds_bow))
print("Macro F1:", round(macro_f1_bow, 4))
print("Confusion matrix:\n", confusion_matrix(y_val, preds_bow))



# 2. Linear SVM on TF-IDF

clf_tfidf = LinearSVC(C=0.001, class_weight='balanced', random_state=42)
clf_tfidf.fit(X_train_tfidf, y_train)

# Predictions
preds_tfidf = clf_tfidf.predict(X_val_tfidf)

# Macro F1
macro_f1_tfidf = f1_score(y_val, preds_tfidf, average='macro')

print("RESULTS: TF-IDF + LinearSVC")
print(classification_report(y_val, preds_tfidf, digits=3))
print("Accuracy:", accuracy_score(y_val, preds_tfidf))
print("Macro F1:", round(macro_f1_tfidf, 4))
print("Confusion matrix:\n", confusion_matrix(y_val, preds_tfidf))
# Out:
# RESULTS: Bag-of-Words + LinearSVC
#               precision    recall  f1-score   support
#
#            0      0.966     0.787     0.868       512
#            1      0.398     0.837     0.539        86
#
#     accuracy                          0.794       598
#    macro avg      0.682     0.812     0.703       598
# weighted avg      0.885     0.794     0.820       598
#
# Accuracy: 0.794314381270903
# Macro F1: 0.7035
# Confusion matrix:
#  [[403 109]
#  [ 14  72]]
# RESULTS: TF-IDF + LinearSVC
#               precision    recall  f1-score   support
#
#            0      0.958     0.809     0.877       512
#            1      0.410     0.791     0.540        86
#
#     accuracy                          0.806       598
#    macro avg      0.684     0.800     0.708       598
# weighted avg      0.879     0.806     0.829       598
#
# Accuracy: 0.8060200668896321
# Macro F1: 0.7084
# Confusion matrix:
#  [[414  98]
#  [ 18  68]]
# /Users/giulia/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# /Users/giulia/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(

# %% [markdown]
# Both vectorizations perform similarly with LinearSVC. TF-IDF achieves a slightly higher macro F1 (0.7084) than Bag-of-Words (0.7035).
#
# The consideration of the biography brings better results compared to those achived with the same models but using only the tweet.

# %% [markdown]
# ## Logistic Distribution

# %% [markdown]
# This cell trains two Logistic Regression models—one using Bag-of-Words and the other using TF–IDF. The parameter `class_weight='balanced'` is used to mitigate the severe label imbalance by assigning a higher weight to the minority class during training.

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, accuracy_score, f1_score


# 1. LOGISTIC REGRESSION on Bag-of-Words

lr_bow = LogisticRegression(
    penalty='l2',
    max_iter=500,
    C=1.0,
    class_weight='balanced',
    random_state=42,
    n_jobs=-1
)

lr_bow.fit(X_train_bow, y_train)

# Predictions
preds_bow = lr_bow.predict(X_val_bow)

# Metrics
print("RESULTS: Logistic Regression (Bag-of-Words)")
print(classification_report(y_val, preds_bow))
print("Accuracy:", accuracy_score(y_val, preds_bow))
print("Macro F1:", f1_score(y_val, preds_bow, average='macro'))


# 2. LOGISTIC REGRESSION on TF-IDF

lr_tfidf = LogisticRegression(
    penalty='l2',
    max_iter=500,
    C=1.0,
    class_weight='balanced',
    random_state=42,
    n_jobs=-1
)

lr_tfidf.fit(X_train_tfidf, y_train)

# Predictions
preds_tfidf = lr_tfidf.predict(X_val_tfidf)

# Metrics
print("\nRESULTS: Logistic Regression (TF-IDF)")
print(classification_report(y_val, preds_tfidf))
print("Accuracy:", accuracy_score(y_val, preds_tfidf))
print("Macro F1:", f1_score(y_val, preds_tfidf, average='macro'))
# Out:
# RESULTS: Logistic Regression (Bag-of-Words)
#               precision    recall  f1-score   support
#
#            0       0.94      0.93      0.94       512
#            1       0.62      0.66      0.64        86
#
#     accuracy                           0.89       598
#    macro avg       0.78      0.80      0.79       598
# weighted avg       0.90      0.89      0.89       598
#
# Accuracy: 0.8929765886287625
# Macro F1: 0.7887905344252886
#
# RESULTS: Logistic Regression (TF-IDF)
#               precision    recall  f1-score   support
#
#            0       0.94      0.90      0.92       512
#            1       0.53      0.65      0.59        86
#
#     accuracy                           0.87       598
#    macro avg       0.74      0.78      0.75       598
# weighted avg       0.88      0.87      0.87       598
#
# Accuracy: 0.8678929765886287
# Macro F1: 0.7538902346904222

# %% [markdown]
# Both Bag-of-Words and TF-IDF representations produce strong performance with Logistic Regression in the multilingual setting. However, Bag-of-Words clearly performs better overall:
#
# - Higher precision, recall, and F1-score for the minority class (label 1): BoW F1 for class 1 ≈ 0.64 vs. TF-IDF ≈ 0.59
# - Higher Macro F1: BoW Macro F1 = 0.789; TF-IDF Macro F1 = 0.754
# - Higher overall accuracy: BoW accuracy ≈ 0.893; TF-IDF accuracy ≈ 0.868
#
# This indicates that BoW better captures the multilingual discriminatory patterns in this dataset. It is especially more effective at recalling and classifying the minority (hate speech) class, which is the key challenge of the task.
#
# Best model so far: Logistic Regression + Bag-of-Words, which achieves the strongest balance between accuracy and fairness across classes.

# %% [markdown]
# # 8. Evaluation of the best performing model: BoW + Logistic Regression

# %%
# 1. Re–train BoW + Logistic Regression on all labeled data

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.linear_model import LogisticRegression
import joblib

# Full text and labels
text_full = train_multi["text_clean"]
y_full    = train_multi["label"].values

# Final BoW vectorizer (same config as validation stage)
vectorizer_bow_final = CountVectorizer(
    ngram_range=(1,3),
    max_features=10000
)

# Fit on all labeled data
X_full_bow = vectorizer_bow_final.fit_transform(text_full)

print("Full train BoW shape:", X_full_bow.shape)

# Save vectorizer
joblib.dump(vectorizer_bow_final, "vectorizer_bow_final.save")
# Out:
# Full train BoW shape: (2988, 10000)
# ['vectorizer_bow_final.save']

# %%
# 2. Train of the best model on all the data

lr_bow_final = LogisticRegression(
    penalty='l2',
    max_iter=500,
    C=1,
    class_weight='balanced',
    random_state=42,
    n_jobs=-1
)

lr_bow_final.fit(X_full_bow, y_full)

# Save model
joblib.dump(lr_bow_final, "lr_bow_final.save")
# Out:
# ['lr_bow_final.save']

# %%
# 3. Trasformation of the test set and predictions

# Preprocessed test text
X_test_text = test_multi["text_clean"]

# Load vectorizer
vectorizer = joblib.load("vectorizer_bow_final.save")

# Transform test
X_test_bow = vectorizer.transform(X_test_text)

print("Test BoW shape:", X_test_bow.shape)

# Load model
best_model = joblib.load("lr_bow_final.save")

# Predict labels
preds_test = best_model.predict(X_test_bow)
# Out:
# Test BoW shape: (1995, 10000)

# %%
submissionTaskB = pd.DataFrame({
    "id": test_multi["id"],
    "label": preds_test,
    "lang": test_multi["lang"]
})

submissionTaskB.to_csv("submission_taskB.tsv", sep="\t", index=False)
print("Submission file created: submission_taskB.tsv")
submissionTaskB
# Out:
# Submission file created: submission_taskB.tsv
#            id  label lang
# 0      it_406      1   it
# 1      it_138      0   it
# 2     it_1622      1   it
# 3     it_1401      0   it
# 4      it_807      1   it
# 5      it_566      1   it
# 6     it_1344      0   it
# 7      it_732      0   it
# 8      it_347      0   it
# 9       it_56      0   it
# 10    it_1540      0   it
# 11    it_1187      0   it
# 12     it_647      0   it
# 13    it_1394      0   it
# 14    it_1757      0   it
# 15      it_13      0   it
# 16    it_1512      0   it
# 17    it_1586      0   it
# 18    it_1726      0   it
# 19     it_513      0   it
# 20     it_748      0   it
# 21    it_1479      0   it
# 22     it_639      0   it
# 23     it_933      0   it
# 24     it_323      1   it
# 25     it_825      0   it
# 26    it_1617      0   it
# 27    it_1573      0   it
# 28     it_821      0   it
# 29     it_819      0   it
# 30    it_1071      1   it
# 31    it_1386      0   it
# 32     it_204      0   it
# 33    it_1635      0   it
# 34     it_733      0   it
# 35     it_183      0   it
# 36     it_671      0   it
# 37     it_202      1   it
# 38     it_857      0   it
# 39     it_585      0   it
# 40    it_1466      0   it
# 41    it_1213      0   it
# 42    it_1527      0   it
# 43     it_767      0   it
# 44     it_371      0   it
# 45    it_1195      0   it
# 46    it_1242      0   it
# 47    it_1582      0   it
# 48      it_87      0   it
# 49     it_884      0   it
# 50    it_1405      0   it
# 51    it_1334      0   it
# 52     it_947      0   it
# 53      it_64      0   it
# 54     it_923      0   it
# 55    it_1194      0   it
# 56     it_462      0   it
# 57     it_957      0   it
# 58     it_895      1   it
# 59     it_486      0   it
# 60    it_1209      0   it
# 61     it_914      0   it
# 62    it_1432      0   it
# 63      it_27      0   it
# 64     it_239      0   it
# 65     it_254      0   it
# 66    it_1597      1   it
# 67     it_357      0   it
# 68    it_1667      1   it
# 69     it_395      0   it
# 70     it_793      0   it
# 71     it_145      0   it
# 72     it_852      0   it
# 73    it_1369      0   it
# 74    it_1744      0   it
# 75    it_1004      0   it
# 76    it_1436      0   it
# 77    it_1521      0   it
# 78      it_83      0   it
# 79    it_1585      1   it
# 80     it_854      0   it
# 81     it_125      0   it
# 82     it_429      0   it
# 83    it_1376      0   it
# 84     it_681      0   it
# 85     it_352      0   it
# 86      it_52      0   it
# 87     it_266      0   it
# 88    it_1655      0   it
# 89    it_1747      1   it
# 90     it_818      0   it
# 91     it_573      0   it
# 92      it_37      0   it
# 93     it_543      0   it
# 94      it_17      0   it
# 95    it_1317      0   it
# 96     it_738      0   it
# 97    it_1138      0   it
# 98     it_314      1   it
# 99     it_693      0   it
# 100   it_1495      0   it
# 101     it_49      0   it
# 102    it_820      0   it
# 103    it_515      0   it
# 104   it_1112      0   it
# 105    it_487      1   it
# 106   it_1378      0   it
# 107   it_1235      0   it
# 108   it_1158      0   it
# 109    it_553      0   it
# 110    it_955      0   it
# 111    it_747      1   it
# 112   it_1686      1   it
# 113    it_418      0   it
# 114   it_1430      0   it
# 115    it_790      0   it
# 116    it_296      0   it
# 117   it_1777      0   it
# 118   it_1074      0   it
# 119    it_475      0   it
# 120   it_1663      0   it
# 121    it_906      0   it
# 122    it_391      0   it
# 123   it_1333      0   it
# 124    it_932      0   it
# 125    it_804      0   it
# 126   it_1148      0   it
# 127   it_1695      0   it
# 128   it_1701      0   it
# 129   it_1781      0   it
# 130    it_263      0   it
# 131    it_841      0   it
# 132    it_984      0   it
# 133   it_1403      1   it
# 134   it_1034      0   it
# 135    it_853      0   it
# 136   it_1610      0   it
# 137    it_474      1   it
# 138   it_1691      0   it
# 139   it_1176      0   it
# 140     it_24      0   it
# 141    it_998      1   it
# 142    it_631      0   it
# 143   it_1324      1   it
# 144    it_308      0   it
# 145    it_870      0   it
# 146     it_99      0   it
# 147   it_1806      1   it
# 148     it_29      1   it
# 149   it_1461      0   it
# 150    it_724      0   it
# 151   it_1625      0   it
# 152    it_478      0   it
# 153    it_942      0   it
# 154   it_1480      0   it
# 155    it_455      0   it
# 156    it_783      1   it
# 157     it_22      0   it
# 158    it_535      0   it
# 159    it_645      0   it
# 160    it_264      1   it
# 161    it_230      0   it
# 162    it_911      0   it
# 163    it_344      0   it
# 164    it_808      0   it
# 165    it_244      0   it
# 166   it_1427      0   it
# 167   it_1099      0   it
# 168    it_636      0   it
# 169    it_594      1   it
# 170   it_1541      0   it
# 171    it_342      1   it
# 172    it_991      0   it
# 173    it_695      0   it
# 174   it_1468      0   it
# 175    it_704      0   it
# 176   it_1275      1   it
# 177   it_1038      0   it
# 178   it_1692      0   it
# 179   it_1594      0   it
# 180    it_616      0   it
# 181    it_780      0   it
# 182   it_1174      1   it
# 183    it_637      1   it
# 184   it_1476      0   it
# 185   it_1803      0   it
# 186    it_197      0   it
# 187    it_741      0   it
# 188    it_805      0   it
# 189    it_334      0   it
# 190    it_589      1   it
# 191    it_782      0   it
# 192   it_1689      0   it
# 193   it_1214      0   it
# 194    it_617      0   it
# 195   it_1762      0   it
# 196    it_592      0   it
# 197   it_1375      1   it
# 198    it_653      0   it
# 199   it_1265      0   it
# 200   it_1111      0   it
# 201   it_1189      0   it
# 202    it_191      0   it
# 203    it_287      0   it
# 204     it_92      0   it
# 205    it_502      1   it
# 206   it_1698      0   it
# 207     it_33      0   it
# 208    it_992      0   it
# 209    it_698      0   it
# 210    it_377      0   it
# 211    it_862      0   it
# 212    it_789      1   it
# 213    it_903      0   it
# 214     it_47      0   it
# 215    it_488      0   it
# 216   it_1030      0   it
# 217    it_451      0   it
# 218    it_882      1   it
# 219    it_166      0   it
# 220    it_492      0   it
# 221    it_477      0   it
# 222    it_746      1   it
# 223    it_799      0   it
# 224   it_1716      0   it
# 225    it_291      1   it
# 226   it_1236      0   it
# 227   it_1784      1   it
# 228      it_5      0   it
# 229    it_234      0   it
# 230   it_1245      0   it
# 231   it_1517      0   it
# 232   it_1808      0   it
# 233   it_1647      0   it
# 234   it_1494      0   it
# 235   it_1175      0   it
# 236    it_235      0   it
# 237   it_1292      0   it
# 238   it_1670      0   it
# 239   it_1006      0   it
# 240   it_1804      0   it
# 241    it_650      1   it
# 242    it_316      1   it
# 243     it_20      0   it
# 244    it_873      0   it
# 245    it_798      0   it
# 246    it_760      0   it
# 247    it_633      0   it
# 248     it_72      0   it
# 249    it_313      1   it
# 250    it_269      0   it
# 251    it_463      1   it
# 252    it_866      0   it
# 253    it_970      0   it
# 254   it_1154      0   it
# 255   it_1001      0   it
# 256   it_1654      1   it
# 257   it_1294      0   it
# 258   it_1754      0   it
# 259   it_1027      0   it
# 260    it_847      0   it
# 261    it_393      0   it
# 262    it_189      1   it
# 263    it_978      0   it
# 264    it_222      0   it
# 265   it_1092      0   it
# 266    it_282      0   it
# 267   it_1391      0   it
# 268    it_869      0   it
# 269   it_1547      0   it
# 270   it_1279      0   it
# 271    it_801      0   it
# 272   it_1440      0   it
# 273    it_415      1   it
# 274    it_186      0   it
# 275    it_861      0   it
# 276    it_586      0   it
# 277    it_864      0   it
# 278   it_1314      0   it
# 279    it_500      0   it
# 280    it_778      1   it
# 281    it_272      0   it
# 282   it_1392      0   it
# 283     it_28      0   it
# 284   it_1734      0   it
# 285    it_243      1   it
# 286    it_217      0   it
# 287     it_74      1   it
# 288    it_498      0   it
# 289    it_116      0   it
# 290   it_1673      0   it
# 291    it_453      0   it
# 292   it_1328      0   it
# 293     it_94      1   it
# 294    it_399      0   it
# 295     it_15      0   it
# 296    it_161      0   it
# 297   it_1509      0   it
# 298    it_207      0   it
# 299   it_1601      0   it
# 300    it_989      1   it
# 301   it_1490      1   it
# 302   it_1525      0   it
# 303    it_214      0   it
# 304    it_469      0   it
# 305   it_1704      0   it
# 306    it_680      0   it
# 307   it_1418      0   it
# 308   it_1301      0   it
# 309    it_301      0   it
# 310   it_1603      0   it
# 311    it_930      0   it
# 312    it_756      1   it
# 313   it_1370      0   it
# 314   it_1710      0   it
# 315   it_1263      0   it
# 316    it_465      0   it
# 317   it_1044      0   it
# 318   it_1128      0   it
# 319   it_1260      0   it
# 320   it_1182      1   it
# 321    it_112      0   it
# 322   it_1510      0   it
# 323   it_1070      0   it
# 324    it_326      1   it
# 325    it_525      1   it
# 326    it_325      0   it
# 327    it_995      0   it
# 328   it_1081      0   it
# 329    it_604      0   it
# 330   it_1286      0   it
# 331    it_855      0   it
# 332   it_1226      1   it
# 333    it_610      0   it
# 334    it_985      0   it
# 335   it_1156      1   it
# 336   it_1755      0   it
# 337    it_198      1   it
# 338   it_1576      1   it
# 339   it_1089      0   it
# 340   it_1095      0   it
# 341    it_456      0   it
# 342   it_1207      0   it
# 343    it_275      0   it
# 344   it_1222      1   it
# 345   it_1708      1   it
# 346    it_549      1   it
# 347    it_956      0   it
# 348   it_1532      0   it
# 349    it_247      0   it
# 350   it_1531      0   it
# 351   it_1649      0   it
# 352   it_1083      0   it
# 353   it_1600      0   it
# 354    it_318      0   it
# 355    it_851      0   it
# 356   it_1354      1   it
# 357    it_358      1   it
# 358   it_1660      0   it
# 359    it_613      0   it
# 360    it_188      0   it
# 361    it_426      0   it
# 362    it_115      0   it
# 363    it_232      0   it
# 364   it_1119      0   it
# 365   it_1329      0   it
# 366   it_1169      1   it
# 367   it_1556      0   it
# 368   it_1164      1   it
# 369   it_1315      0   it
# 370     it_57      0   it
# 371   it_1129      0   it
# 372   it_1724      0   it
# 373   it_1467      0   it
# 374   it_1364      1   it
# 375   it_1063      0   it
# 376   it_1682      0   it
# 377    it_708      0   it
# 378   it_1090      0   it
# 379   it_1057      0   it
# 380    it_348      0   it
# 381    it_975      0   it
# 382     it_50      0   it
# 383   it_1048      0   it
# 384    it_777      0   it
# 385    it_904      1   it
# 386    it_180      0   it
# 387    it_147      0   it
# 388   it_1651      1   it
# 389   it_1539      0   it
# 390   it_1201      0   it
# 391    it_332      0   it
# 392    it_190      1   it
# 393    it_369      0   it
# 394    it_143      0   it
# 395    it_407      0   it
# 396   it_1254      0   it
# 397    it_519      0   it
# 398    it_420      0   it
# 399   it_1760      0   it
# 400   it_1730      0   it
# 401    it_621      0   it
# 402    it_751      0   it
# 403   it_1643      0   it
# 404    it_505      0   it
# 405   it_1042      0   it
# 406   it_1700      0   it
# 407    it_221      0   it
# 408    it_311      0   it
# 409    it_424      0   it
# 410    it_167      0   it
# 411   it_1180      0   it
# 412   it_1093      0   it
# 413   it_1764      1   it
# 414    it_716      0   it
# 415   it_1026      0   it
# 416    it_902      0   it
# 417    it_635      0   it
# 418    it_578      0   it
# 419    it_441      0   it
# 420   it_1186      1   it
# 421   it_1404      0   it
# 422   it_1184      0   it
# 423    it_100      0   it
# 424   it_1478      0   it
# 425    it_762      1   it
# 426    it_858      0   it
# 427    it_155      0   it
# 428    it_195      0   it
# 429    it_643      0   it
# 430   it_1064      0   it
# 431   it_1146      0   it
# 432   it_1066      0   it
# 433   it_1758      0   it
# 434    it_136      0   it
# 435    it_537      0   it
# 436    it_464      1   it
# 437   it_1455      0   it
# 438   it_1465      0   it
# 439   it_1572      0   it
# 440    it_423      0   it
# 441   it_1721      0   it
# 442   it_1339      0   it
# 443    it_791      0   it
# 444   it_1528      0   it
# 445    it_193      1   it
# 446    it_130      0   it
# 447    it_875      0   it
# 448   it_1336      0   it
# 449   it_1091      1   it
# 450    it_200      0   it
# 451   it_1563      0   it
# 452    it_710      0   it
# 453   it_1084      0   it
# 454   it_1257      0   it
# 455     it_48      1   it
# 456    it_281      0   it
# 457    it_726      1   it
# 458    it_753      0   it
# 459   it_1659      0   it
# 460   it_1448      1   it
# 461    it_755      0   it
# 462   it_1557      1   it
# 463    it_303      0   it
# 464   it_1646      0   it
# 465   it_1612      0   it
# 466   it_1017      0   it
# 467     it_18      0   it
# 468   it_1714      1   it
# 469     it_36      1   it
# 470   it_1550      0   it
# 471   it_1690      0   it
# 472   it_1326      0   it
# 473   it_1196      0   it
# 474   it_1558      1   it
# 475   it_1740      1   it
# 476   it_1149      0   it
# 477   it_1249      0   it
# 478     it_98      0   it
# 479    it_481      0   it
# 480    it_206      0   it
# 481   it_1750      0   it
# 482   it_1552      0   it
# 483   it_1561      0   it
# 484   it_1179      0   it
# 485   it_1428      0   it
# 486    it_496      0   it
# 487   it_1131      0   it
# 488   it_1251      0   it
# 489    it_187      0   it
# 490    it_893      0   it
# 491   it_1019      0   it
# 492    it_686      0   it
# 493   it_1417      0   it
# 494    it_816      0   it
# 495    it_620      0   it
# 496    it_703      0   it
# 497   it_1130      0   it
# 498   it_1590      0   it
# 499   it_1511      0   it
# 500   it_1212      1   it
# 501   it_1319      0   it
# 502    it_114      0   it
# 503   it_1382      0   it
# 504    it_590      1   it
# 505   it_1723      0   it
# 506   it_1598      0   it
# 507    it_609      0   it
# 508   it_1050      0   it
# 509    it_859      0   it
# 510   it_1780      0   it
# 511     it_31      0   it
# 512   it_1420      0   it
# 513   it_1611      0   it
# 514   it_1727      0   it
# 515    it_949      0   it
# 516   it_1569      1   it
# 517   it_1484      0   it
# 518   it_1244      0   it
# 519    it_999      0   it
# 520    it_396      1   it
# 521    it_944      0   it
# 522   it_1665      0   it
# 523    it_934      0   it
# 524   it_1345      1   it
# 525    it_411      0   it
# 526     it_25      0   it
# 527   it_1181      0   it
# 528   it_1562      0   it
# 529   it_1309      0   it
# 530    it_828      0   it
# 531   it_1773      0   it
# 532   it_1137      0   it
# 533   it_1580      0   it
# 534   it_1596      0   it
# 535   it_1453      1   it
# 536    it_705      0   it
# 537    it_380      0   it
# 538   it_1113      0   it
# 539    it_421      0   it
# 540   it_1485      0   it
# 541    it_937      0   it
# 542    it_626      0   it
# 543   it_1589      0   it
# 544    it_907      0   it
# 545   it_1653      1   it
# 546    it_582      0   it
# 547    it_362      0   it
# 548   it_1395      0   it
# 549    it_849      1   it
# 550    it_246      0   it
# 551     it_68      1   it
# 552   it_1387      0   it
# 553   it_1624      0   it
# 554   it_1233      0   it
# 555    it_494      0   it
# 556   it_1302      0   it
# 557   it_1409      0   it
# 558     it_44      1   it
# 559   it_1365      1   it
# 560    it_605      0   it
# 561   it_1183      0   it
# 562   it_1633      0   it
# 563    it_327      0   it
# 564    it_897      1   it
# 565   it_1098      0   it
# 566   it_1656      0   it
# 567   it_1228      0   it
# 568   it_1058      0   it
# 569    it_228      0   it
# 570   it_1039      0   it
# 571    it_622      0   it
# 572   it_1564      0   it
# 573    it_887      0   it
# 574    it_267      0   it
# 575    it_628      0   it
# 576   it_1514      0   it
# 577    it_522      0   it
# 578   it_1267      0   it
# 579     it_61      1   it
# 580   it_1619      0   it
# 581     it_93      0   it
# 582   it_1255      0   it
# 583   it_1515      1   it
# 584   it_1503      0   it
# 585   it_1102      0   it
# 586    it_917      0   it
# 587   it_1769      0   it
# 588     it_51      1   it
# 589    it_569      0   it
# 590   it_1031      0   it
# 591    it_920      0   it
# 592    it_552      0   it
# 593    it_229      0   it
# 594    it_676      0   it
# 595    it_524      1   it
# 596   it_1229      0   it
# 597   it_1285      0   it
# 598    it_489      0   it
# 599    it_499      0   it
# 600    it_171      0   it
# 601    it_981      0   it
# 602    it_687      0   it
# 603   it_1644      0   it
# 604    it_624      0   it
# 605     it_86      0   it
# 606   it_1341      1   it
# 607    it_965      1   it
# 608    it_248      1   it
# 609    it_121      0   it
# 610    it_256      0   it
# 611    it_963      0   it
# 612    it_309      0   it
# 613    it_856      1   it
# 614   it_1592      1   it
# 615    it_253      0   it
# 616    it_608      0   it
# 617    it_550      0   it
# 618    it_199      0   it
# 619    it_209      0   it
# 620   it_1106      0   it
# 621   it_1079      0   it
# 622   it_1790      0   it
# 623    it_929      0   it
# 624    it_913      1   it
# 625   it_1107      0   it
# 626    it_642      1   it
# 627   it_1638      0   it
# 628    it_946      1   it
# 629   it_1751      0   it
# 630   it_1086      0   it
# 631   it_1554      0   it
# 632    it_815      0   it
# 633    it_668      1   it
# 634   it_1139      0   it
# 635    it_577      0   it
# 636   it_1697      0   it
# 637   it_1272      0   it
# 638    it_152      1   it
# 639   it_1266      0   it
# 640   it_1679      0   it
# 641    it_381      1   it
# 642    it_201      1   it
# 643   it_1608      0   it
# 644   it_1293      1   it
# 645   it_1607      0   it
# 646   it_1094      0   it
# 647    it_568      0   it
# 648    it_249      0   it
# 649   it_1449      0   it
# 650    it_572      1   it
# 651    it_564      0   it
# 652    it_503      1   it
# 653   it_1807      0   it
# 654    it_376      0   it
# 655    it_806      0   it
# 656   it_1007      0   it
# 657     it_10      0   it
# 658    it_986      1   it
# 659    it_141      1   it
# 660    it_299      1   it
# 661    it_324      0   it
# 662   it_1040      0   it
# 663   it_1518      0   it
# 664     it_26      0   it
# 665   it_1397      0   it
# 666   it_1258      0   it
# 667    it_491      0   it
# 668    it_649      0   it
# 669    it_979      1   it
# 670    it_338      0   it
# 671   it_1793      0   it
# 672    it_822      0   it
# 673   it_1145      0   it
# 674   it_1320      1   it
# 675    it_719      0   it
# 676    it_284      1   it
# 677   it_1767      1   it
# 678   it_1147      1   it
# 679   it_1204      0   it
# 680    it_237      0   it
# 681    it_612      0   it
# 682    it_154      0   it
# 683    it_356      0   it
# 684   it_1516      0   it
# 685    it_118      0   it
# 686    it_797      1   it
# 687   it_1426      0   it
# 688   it_1037      0   it
# 689   it_1338      1   it
# 690    it_567      0   it
# 691   it_1415      0   it
# 692    it_761      0   it
# 693   it_1575      0   it
# 694    it_497      0   it
# 695    it_967      0   it
# 696   it_1353      0   it
# 697   it_1060      0   it
# 698    it_520      0   it
# 699    it_826      0   it
# 700    it_468      0   it
# 701   it_1061      0   it
# 702    it_966      0   it
# 703    it_953      0   it
# 704    it_593      0   it
# 705     it_81      1   it
# 706    it_506      0   it
# 707    it_165      0   it
# 708     it_46      0   it
# 709    it_973      1   it
# 710   it_1203      0   it
# 711   it_1571      1   it
# 712    it_169      1   it
# 713   it_1694      0   it
# 714    it_241      0   it
# 715   it_1712      0   it
# 716   it_1483      0   it
# 717   it_1614      0   it
# 718    it_596      0   it
# 719    it_921      0   it
# 720      it_2      0   it
# 721    it_587      0   it
# 722    it_702      0   it
# 723   it_1732      0   it
# 724    it_812      0   it
